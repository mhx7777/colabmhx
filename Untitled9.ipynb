# %% [markdown]
# <a href="https://colab.research.google.com/github/mhx7777/colabmhx/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/zuihouyici.zip -d /content/yui
# Out:
# Archive:  /content/zuihouyici.zip
#    creating: /content/yui/ultralytics-main/
#    creating: /content/yui/ultralytics-main/.github/
#   inflating: /content/yui/ultralytics-main/.github/dependabot.yml
#    creating: /content/yui/ultralytics-main/.github/ISSUE_TEMPLATE/
#   inflating: /content/yui/ultralytics-main/.github/ISSUE_TEMPLATE/bug-report.yml
#   inflating: /content/yui/ultralytics-main/.github/ISSUE_TEMPLATE/config.yml
#   inflating: /content/yui/ultralytics-main/.github/ISSUE_TEMPLATE/feature-request.yml
#   inflating: /content/yui/ultralytics-main/.github/ISSUE_TEMPLATE/question.yml
#    creating: /content/yui/ultralytics-main/.github/workflows/
#   inflating: /content/yui/ultralytics-main/.github/workflows/ci.yaml
#   inflating: /content/yui/ultralytics-main/.github/workflows/cla.yml
#   inflating: /content/yui/ultralytics-main/.github/workflows/docker.yaml
#   inflating: /content/yui/ultralytics-main/.github/workflows/docs.yml
# ...

# %%
# %cd /content/yui/ultralytics-main
# Out:
# /content/yui/ultralytics-main

# %%
# !python train_test.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics 8.3.47 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
